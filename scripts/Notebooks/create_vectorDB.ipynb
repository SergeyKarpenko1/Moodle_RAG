# %%
from pathlib import Path
import os
import ast
import re
from typing import Tuple, Dict, Any, List

from dotenv import load_dotenv
from langchain_core.documents import Document
from langchain_chroma import Chroma
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langdetect import detect
from deep_translator import GoogleTranslator

# %%
load_dotenv()

CHUNKS_DIR = Path(os.environ["MOODLE_CHUNKS_DIR"])
PERSIST_DIR = os.environ["MOODLE_CHROMA_DB_DIR"]
COLLECTION_NAME = os.environ.get("MOODLE_COLLECTION_NAME", "moodle_docs")

# %%
model_name = "BAAI/bge-base-en-v1.5"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
hf_embeddings = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)

# %%
def parse_chunk_file(path: Path) -> Tuple[str, Dict[str, Any]]:
    text = path.read_text(encoding="utf-8").strip()

    # Ожидаем формат:
    # ---
    # {'doc_title': ..., ...}
    # ---
    # <content>
    m = re.match(r"^\s*---\s*\n(.*?)\n---\s*\n?(.*)$", text, flags=re.DOTALL)
    if not m:
        # если вдруг файл без меты
        return text, {"source_file": str(path)}

    meta_str = m.group(1).strip()
    content = m.group(2).strip()

    try:
        metadata = ast.literal_eval(meta_str)  # т.к. у тебя сейчас python dict строкой
        if not isinstance(metadata, dict):
            metadata = {}
    except Exception:
        metadata = {}

    metadata["source_file"] = str(path)
    return content, metadata

# %%
docs: List[Document] = []

for chunk_path in sorted(CHUNKS_DIR.rglob("chunk_*.md")):
    content, metadata = parse_chunk_file(chunk_path)
    if not content.strip():
        continue
    docs.append(Document(page_content=content, metadata=metadata))

print(f"Loaded documents: {len(docs)}")
# Out:
# Loaded documents: 2697

# %%
# убираем пустые списки в metadata иначе chroma падает

for d in docs:
    d.metadata = {
        k: v for k, v in d.metadata.items()
        if not (isinstance(v, list) and len(v) == 0)
    }

# %%
batch_size = 1000

vector_store = Chroma(
    collection_name=COLLECTION_NAME,
    embedding_function=hf_embeddings,
    persist_directory=PERSIST_DIR,
)

for i in range(0, len(docs), batch_size):
    vector_store.add_documents(docs[i:i + batch_size])

print("Indexed:", len(docs))
# Out:
# Indexed: 2697

# %%
query = "How do I create a new course in Moodle?"

results = vector_store.similarity_search_with_score(query, k=3)

for i, (doc, score) in enumerate(results, 1):
    sim = 1 - score

    print(f"\n=== Result {i} ===")
    print("Similarity:", sim)              # больше = лучше
    print("Metadata:", doc.metadata)
    print("Text preview:", doc.page_content[:400], "...")
# Out:
# === Result 1 ===
# Similarity: 0.7398324012756348
# Metadata: {'chunk_index': 0, 'source_file': '/Users/sergey/Desktop/Moodle_RAG/data/moodle_docs/chunks_md/403__en__Adding_a_new_course/chunk_0000.md', 'youtube_links': ['https://youtu.be/MzK2jb-9SwE'], 'h2': 'Adding a course', 'h1': 'Adding a new course', 'source_links': ['https://docs.moodle.org/403/en/Adding_a_new_course', 'https://docs.moodle.org/403/en/File:26addcourse1.png', 'https://docs.moodle.org/403/en/File:26defaultcoursevalues.png', 'https://docs.moodle.org/403/en/File:coursesort.png', 'https://docs.moodle.org/403/en/File:template1.png', 'https://docs.moodle.org/403/en/File:template2.png', 'https://docs.moodle.org/403/en/images_en/1/14/26defaultcoursevalues.png', 'https://docs.moodle.org/403/en/images_en/6/60/coursesort.png', 'https://docs.moodle.org/403/en/images_en/f/f5/newcoursesavereturn.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/14/26defaultcoursevalues.png/300px-26defaultcoursevalues.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/14/26defaultcoursevalues.png/450px-26defaultcoursevalues.png', 'https://docs.moodle.org/403/en/images_en/thumb/3/3c/template2.png/400px-template2.png', 'https://docs.moodle.org/403/en/images_en/thumb/3/3c/template2.png/600px-template2.png', 'https://docs.moodle.org/403/en/images_en/thumb/3/3c/template2.png/800px-template2.png', 'https://docs.moodle.org/403/en/images_en/thumb/6/60/coursesort.png/200px-coursesort.png', 'https://docs.moodle.org/403/en/images_en/thumb/6/60/coursesort.png/300px-coursesort.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/7c/26addcourse1.png/400px-26addcourse1.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/7c/26addcourse1.png/600px-26addcourse1.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/7c/26addcourse1.png/800px-26addcourse1.png', 'https://docs.moodle.org/403/en/images_en/thumb/c/c5/template1.png/400px-template1.png', 'https://docs.moodle.org/403/en/images_en/thumb/c/c5/template1.png/600px-template1.png', 'https://docs.moodle.org/403/en/images_en/thumb/c/c5/template1.png/800px-template1.png'], 'doc_title': 'Adding a new course'}
# Text preview: # Adding a new course
# ## Adding a course
# By default a regular teacher can't add a new course. To add a new course to Moodle, you need to have either Administrator, Course Creator or Manager rights.To add a course:
# * From the Site administration link, click Courses>Manage courses and categories
# [](https://docs.moodle.org/403/en/File:26addcourse1.png)Click New course in the category page on the  ...
#
# === Result 2 ===
# Similarity: 0.5992670059204102
# Metadata: {'doc_title': 'Installing Moodle', 'h1': 'chmod 0777 /path/to/moodledata', 'h2': 'Final configuration', 'source_links': ['https://docs.moodle.org/403/en/Installing_Moodle'], 'h3': 'Installation is complete :)', 'chunk_index': 17, 'source_file': '/Users/sergey/Desktop/Moodle_RAG/data/moodle_docs/chunks_md/403__en__Installing_Moodle/chunk_0017.md'}
# Text preview: ### Installation is complete :)
# * Create a new course: You can now access Moodle through your web browser (using the same URL as you set during the install process), log in as your admin user and create a new course. See create a new course.
# * Now that your site is running, when you've got a chance, consider seeing how you can maximize its performance by having a look at Performance recommendation ...
#
# === Result 3 ===
# Similarity: 0.5927504897117615
# Metadata: {'h2': 'Adding courses', 'source_links': ['https://docs.moodle.org/403/en/File:Boost40.png', 'https://docs.moodle.org/403/en/File:Enrol40.png', 'https://docs.moodle.org/403/en/File:badges40.png', 'https://docs.moodle.org/403/en/Guide_for_new_administrators', 'https://docs.moodle.org/403/en/images_en/7/71/Enrol40.png', 'https://docs.moodle.org/403/en/images_en/8/8c/badges40.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/17/Boost40.png/1200px-Boost40.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/17/Boost40.png/600px-Boost40.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/17/Boost40.png/900px-Boost40.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/71/Enrol40.png/600px-Enrol40.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/71/Enrol40.png/900px-Enrol40.png', 'https://docs.moodle.org/403/en/images_en/thumb/8/8c/badges40.png/600px-badges40.png', 'https://docs.moodle.org/403/en/images_en/thumb/8/8c/badges40.png/900px-badges40.png'], 'doc_title': 'Admin quick guide', 'source_file': '/Users/sergey/Desktop/Moodle_RAG/data/moodle_docs/chunks_md/403__en__Guide_for_new_administrators/chunk_0003.md', 'chunk_index': 3, 'h1': 'Admin quick guide'}
# Text preview: ## Adding courses
# * Courses are Moodle's learning areas, where teachers and students work together.
# * You may add a new course by clicking the 'Add a new course' button on the front page or from the Manage courses and categories link in the Courses area of Site administration.
# * If you plan to have many courses, you can upload courses in bulk via CSV file.
# * If you want certain settings in your co ...

# %%
def prepare_query(user_query: str):
    lang = detect(user_query)
    if lang == "ru":
        query_en = GoogleTranslator(source="ru", target="en").translate(user_query)
    else:
        query_en = user_query
    return query_en, lang

# %%
# короткая проверка translate -> retrieve + similarity

user_query = "Как создать новый курс в Moodle?"

query_en, user_lang = prepare_query(user_query)
results = vector_store.similarity_search_with_score(query_en, k=5)

print("user_lang:", user_lang)
print("query_en:", query_en)
print("retrieved:", len(results))

for i, (doc, score) in enumerate(results, 1):
    sim = 1 - score  # условная cosine similarity

    print(f"\n=== Result {i} ===")
    print("Similarity:", sim)          # больше = лучше
    print("Metadata:", doc.metadata)
    print("Text preview:", doc.page_content[:400], "...")
# Out:
# user_lang: ru
# query_en: How to create a new course in Moodle?
# retrieved: 5
#
# === Result 1 ===
# Similarity: 0.7389518618583679
# Metadata: {'youtube_links': ['https://youtu.be/MzK2jb-9SwE'], 'chunk_index': 0, 'h2': 'Adding a course', 'source_links': ['https://docs.moodle.org/403/en/Adding_a_new_course', 'https://docs.moodle.org/403/en/File:26addcourse1.png', 'https://docs.moodle.org/403/en/File:26defaultcoursevalues.png', 'https://docs.moodle.org/403/en/File:coursesort.png', 'https://docs.moodle.org/403/en/File:template1.png', 'https://docs.moodle.org/403/en/File:template2.png', 'https://docs.moodle.org/403/en/images_en/1/14/26defaultcoursevalues.png', 'https://docs.moodle.org/403/en/images_en/6/60/coursesort.png', 'https://docs.moodle.org/403/en/images_en/f/f5/newcoursesavereturn.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/14/26defaultcoursevalues.png/300px-26defaultcoursevalues.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/14/26defaultcoursevalues.png/450px-26defaultcoursevalues.png', 'https://docs.moodle.org/403/en/images_en/thumb/3/3c/template2.png/400px-template2.png', 'https://docs.moodle.org/403/en/images_en/thumb/3/3c/template2.png/600px-template2.png', 'https://docs.moodle.org/403/en/images_en/thumb/3/3c/template2.png/800px-template2.png', 'https://docs.moodle.org/403/en/images_en/thumb/6/60/coursesort.png/200px-coursesort.png', 'https://docs.moodle.org/403/en/images_en/thumb/6/60/coursesort.png/300px-coursesort.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/7c/26addcourse1.png/400px-26addcourse1.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/7c/26addcourse1.png/600px-26addcourse1.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/7c/26addcourse1.png/800px-26addcourse1.png', 'https://docs.moodle.org/403/en/images_en/thumb/c/c5/template1.png/400px-template1.png', 'https://docs.moodle.org/403/en/images_en/thumb/c/c5/template1.png/600px-template1.png', 'https://docs.moodle.org/403/en/images_en/thumb/c/c5/template1.png/800px-template1.png'], 'doc_title': 'Adding a new course', 'source_file': '/Users/sergey/Desktop/Moodle_RAG/data/moodle_docs/chunks_md/403__en__Adding_a_new_course/chunk_0000.md', 'h1': 'Adding a new course'}
# Text preview: # Adding a new course
# ## Adding a course
# By default a regular teacher can't add a new course. To add a new course to Moodle, you need to have either Administrator, Course Creator or Manager rights.To add a course:
# * From the Site administration link, click Courses>Manage courses and categories
# [](https://docs.moodle.org/403/en/File:26addcourse1.png)Click New course in the category page on the  ...
#
# === Result 2 ===
# Similarity: 0.6042138338088989
# Metadata: {'h2': 'Final configuration', 'h1': 'chmod 0777 /path/to/moodledata', 'h3': 'Installation is complete :)', 'source_file': '/Users/sergey/Desktop/Moodle_RAG/data/moodle_docs/chunks_md/403__en__Installing_Moodle/chunk_0017.md', 'source_links': ['https://docs.moodle.org/403/en/Installing_Moodle'], 'doc_title': 'Installing Moodle', 'chunk_index': 17}
# Text preview: ### Installation is complete :)
# * Create a new course: You can now access Moodle through your web browser (using the same URL as you set during the install process), log in as your admin user and create a new course. See create a new course.
# * Now that your site is running, when you've got a chance, consider seeing how you can maximize its performance by having a look at Performance recommendation ...
#
# === Result 3 ===
# Similarity: 0.5983457565307617
# Metadata: {'chunk_index': 0, 'source_file': '/Users/sergey/Desktop/Moodle_RAG/data/moodle_docs/chunks_md/403__en__Managing_a_Moodle_course/chunk_0000.md', 'source_links': ['https://docs.moodle.org/403/en/Managing_a_Moodle_course'], 'youtube_links': ['https://www.youtube.com/watch?index=3&list=PLxcO_MFWQBDehWp4JRrMqUkC-60RBGTs0&v=F9ubp7x2Knw', 'https://www.youtube.com/watch?v=F9ubp7x2Knw&amp%3Bindex=3&amp%3Blist=PLxcO_MFWQBDehWp4JRrMqUkC-60RBGTs0'], 'doc_title': 'Managing a Moodle course', 'h1': 'Managing a Moodle course'}
# Text preview: # Managing a Moodle course
# A _course_ in Moodle is an area where a teacher will add resources and activities for their students to complete. It might be a simple page with downloadable documents or it might be a complex set of tasks where learning progresses through interaction. See the screencast What is a course in Moodle? for an example.
# The course page is made up of central sections which co ...
#
# === Result 4 ===
# Similarity: 0.5976919531822205
# Metadata: {'h2': 'Adding courses', 'h1': 'Admin quick guide', 'source_links': ['https://docs.moodle.org/403/en/Admin_quick_guide', 'https://docs.moodle.org/403/en/File:Boost40.png', 'https://docs.moodle.org/403/en/File:Enrol40.png', 'https://docs.moodle.org/403/en/File:badges40.png', 'https://docs.moodle.org/403/en/images_en/7/71/Enrol40.png', 'https://docs.moodle.org/403/en/images_en/8/8c/badges40.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/17/Boost40.png/1200px-Boost40.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/17/Boost40.png/600px-Boost40.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/17/Boost40.png/900px-Boost40.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/71/Enrol40.png/600px-Enrol40.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/71/Enrol40.png/900px-Enrol40.png', 'https://docs.moodle.org/403/en/images_en/thumb/8/8c/badges40.png/600px-badges40.png', 'https://docs.moodle.org/403/en/images_en/thumb/8/8c/badges40.png/900px-badges40.png'], 'source_file': '/Users/sergey/Desktop/Moodle_RAG/data/moodle_docs/chunks_md/403__en__Admin_quick_guide/chunk_0002.md', 'chunk_index': 2, 'doc_title': 'Admin quick guide'}
# Text preview: ## Adding courses
# * Courses are Moodle's learning areas, where teachers and students work together.
# * You may add a new course by clicking the 'Add a new course' button on the front page or from the Manage courses and categories link in the Courses area of Site administration.
# * If you plan to have many courses, you can upload courses in bulk via CSV file.
# * If you want certain settings in your co ...
#
# === Result 5 ===
# Similarity: 0.5976919531822205
# Metadata: {'source_links': ['https://docs.moodle.org/403/en/File:Boost40.png', 'https://docs.moodle.org/403/en/File:Enrol40.png', 'https://docs.moodle.org/403/en/File:badges40.png', 'https://docs.moodle.org/403/en/Guide_for_new_administrators', 'https://docs.moodle.org/403/en/images_en/7/71/Enrol40.png', 'https://docs.moodle.org/403/en/images_en/8/8c/badges40.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/17/Boost40.png/1200px-Boost40.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/17/Boost40.png/600px-Boost40.png', 'https://docs.moodle.org/403/en/images_en/thumb/1/17/Boost40.png/900px-Boost40.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/71/Enrol40.png/600px-Enrol40.png', 'https://docs.moodle.org/403/en/images_en/thumb/7/71/Enrol40.png/900px-Enrol40.png', 'https://docs.moodle.org/403/en/images_en/thumb/8/8c/badges40.png/600px-badges40.png', 'https://docs.moodle.org/403/en/images_en/thumb/8/8c/badges40.png/900px-badges40.png'], 'source_file': '/Users/sergey/Desktop/Moodle_RAG/data/moodle_docs/chunks_md/403__en__Guide_for_new_administrators/chunk_0003.md', 'h1': 'Admin quick guide', 'chunk_index': 3, 'h2': 'Adding courses', 'doc_title': 'Admin quick guide'}
# Text preview: ## Adding courses
# * Courses are Moodle's learning areas, where teachers and students work together.
# * You may add a new course by clicking the 'Add a new course' button on the front page or from the Manage courses and categories link in the Courses area of Site administration.
# * If you plan to have many courses, you can upload courses in bulk via CSV file.
# * If you want certain settings in your co ...
